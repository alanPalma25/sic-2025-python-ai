# %% [markdown]
# # Actividades Capítulo 2.
#
#
# # Concepto básico de programación e inicio en Python
#
# ## Resumen de actividades
#
# - **Unidad 10.** Tipos de datos lista y tupla Tipos de datos lista y tupla
# - **Unidad 11.** Tipos de datos de diccionario Tipos de datos de diccionario
# - **Unidad 12.** Tipos de datos de secuencia
# - **Unidad 13.** Listas 2D
# - **Unidad 14.** Método del diccionario-1
# - **Unidad 15.** Método del diccionario-2
# - **Unidad 16.** Establecer tipos de datos

# %% [markdown]
# # Actividad: Creación de una Base de Datos en Python
#
# ## Descripción
#
# A continuación debes crear una base de datos simple utilizando listas en Python. Una base de datos es una colección de datos organizados que se utilizan para almacenar y recuperar información. En este caso, simularemos una base de datos de estudiantes con información básica.
#
# ## Instrucciones
#
# 1. Crea un programa en Python que permita a los usuarios realizar las siguientes acciones:
#
#    a. Agregar un nuevo estudiante a la base de datos. Cada estudiante debe tener al menos un nombre, un número de identificación y una edad. Puedes utilizar una lista para almacenar estos datos.
#
#    b. Mostrar la lista de estudiantes en la base de datos.
#
#    c. Buscar un estudiante por su número de identificación y mostrar su información.
#
#    d. Actualizar la información de un estudiante existente en la base de datos.
#
#    e. Eliminar un estudiante de la base de datos.
#
# 2. Utiliza listas de Python para almacenar la información de los estudiantes. Por ejemplo, puedes crear una lista de diccionarios, donde cada diccionario representa un estudiante con sus datos.
#
# 3. Ofrece un menú interactivo que permita a los usuarios elegir las acciones que desean realizar en la base de datos.
#
# 4. Implementa la lógica necesaria para cada acción, como agregar, buscar, actualizar o eliminar estudiantes.
#
# ## Ejemplo de Base de Datos
#
# A continuación, se muestra un ejemplo de cómo podría verse una base de datos de estudiantes utilizando listas y diccionarios:
#
# ```python
# base_de_datos = [
#     {"nombre": "Juan", "id": 1, "edad": 20},
#     {"nombre": "María", "id": 2, "edad": 22},
#     {"nombre": "Carlos", "id": 3, "edad": 21}
# ]
#
# Desarrolle el código en la siguiente lista.

# %%
# Crear una base de datos inicial con dos estudiantes
base_de_datos = [
{"nombre": "Alan", "id" : 1, "edad" : 22},
{"nombre": "Sofía", "id" : 2, "edad" : 23}
]

# ==========================
# Base de Datos de Estudiantes 
# ==========================

# Loop while para mantener el programa activo hasta que el usuario decida salir
while True:
    # Mostrar opciones del menú principal
    print("\n==============================")
    print("   Base de Datos Escolar   ")
    print("==============================")
    print("1. Agregar estudiante")
    print("2. Mostrar estudiantes")
    print("3. Buscar estudiante")
    print("4. Actualizar estudiante")
    print("5. Eliminar estudiante")
    print("0. Salir")

    # Guardar opción seleccionada por el usuario
    opcion = input("Seleccione una opción: ")

    # Estructura match/case (similar a switch/case) para ejecutar la opción seleccionada
    match opcion:
        # Opción 1: Agregar un nuevo estudiante
        case "1":
            nombre = input("Nombre: ")
            id_est = int(input("ID: "))
            edad = int(input("Edad: "))

            id_est_key = False  # Bandera para validar si el ID es único

            # Bucle while para verificar que no exista un estudiante con el mismo ID
            while not id_est_key:
                if any(est["id"] == id_est for est in base_de_datos):
                    print("Ya existe un estudiante con ese ID.")
                    id_est = int(input("ID: "))  # Pedir otro ID si ya existe
                else:
                    id_est_key = True  # ID válido encontrado
            else:
                # Agregar estudiante a la base de datos
                base_de_datos.append({"nombre": nombre, "id": id_est, "edad": edad})
                print("Estudiante agregado.")

        # Opción 2: Mostrar todos los estudiantes registrados
        case "2":
            if not base_de_datos:
                print("La base de datos está vacía.")
            else:
                for est in base_de_datos:
                    print(f"ID: {est['id']:03} | Nombre: {est['nombre']} | Edad: {est['edad']}")

        # Opción 3: Buscar estudiante por su ID
        case "3":
            id_buscar = int(input("Ingrese el ID: "))
            for est in base_de_datos:
                if est["id"] == id_buscar:
                    print(f"ID: {est['id']:03} | Nombre: {est['nombre']} | Edad: {est['edad']}")
                    break
            else:
                print("Estudiante no encontrado.")

        # Opción 4: Actualizar la información de un estudiante
        case "4":
            id_act = int(input("Ingrese el ID del estudiante a actualizar: "))
            for est in base_de_datos:
                if est["id"] == id_act:
                    est["nombre"] = input("Nuevo nombre: ")
                    est["edad"] = int(input("Nueva edad: "))
                    print("Estudiante actualizado.")
                    break
            else:
                print("Estudiante no encontrado.")

        # Opción 5: Eliminar un estudiante de la base de datos
        case "5":
            id_del = int(input("Ingrese el ID del estudiante a eliminar: "))
            for est in base_de_datos:
                if est["id"] == id_del:
                    base_de_datos.remove(est)
                    print("Estudiante eliminado.")
                    break
            else:
                print("Estudiante no encontrado.")

        # Opción 0: Salir del programa
        case "0":
            print("Saliendo")
            break

        # Cualquier otra opción no válida
        case _:
            print("Opción inválida.")
# Out:
# ...
#    Base de Datos Escolar
# ...
# 1. Agregar estudiante
# 2. Mostrar estudiantes
# 3. Buscar estudiante
# 4. Actualizar estudiante
# 5. Eliminar estudiante
# 0. Salir
# Estudiante agregado.
#
# ...
#    Base de Datos Escolar
# ...
# 1. Agregar estudiante
# 2. Mostrar estudiantes
# 3. Buscar estudiante
# 4. Actualizar estudiante
# 5. Eliminar estudiante
# 0. Salir
# ID: 001 | Nombre: Alan | Edad: 22
# ID: 002 | Nombre: Sofía | Edad: 23
# ID: 003 | Nombre: Julio | Edad: 22
#
# ...
#    Base de Datos Escolar
# ...
# 1. Agregar estudiante
# 2. Mostrar estudiantes
# 3. Buscar estudiante
# 4. Actualizar estudiante
# 5. Eliminar estudiante
# 0. Salir
# ID: 003 | Nombre: Julio | Edad: 22
#
# ...
#    Base de Datos Escolar
# ...
# 1. Agregar estudiante
# 2. Mostrar estudiantes
# 3. Buscar estudiante
# 4. Actualizar estudiante
# 5. Eliminar estudiante
# 0. Salir
# Estudiante no encontrado.
#
# ...
#    Base de Datos Escolar
# ...
# 1. Agregar estudiante
# 2. Mostrar estudiantes
# 3. Buscar estudiante
# 4. Actualizar estudiante
# ...

# %% [markdown]
# # Actividad: Rebanado de listas.
#
# Revisa la unidad 10,sección 5.3 aparece un resumen de los comandos para tomar secciones de una lista, aplica los comandos en la siguiente lista:
#
#
# list_notas = [15, 21, 24, 40, 13, 14, 18, 17, 14.5]

# %%
# Espacio para desarrollar las pruebas, si tienes alguna duda o comentario adicional
# lo puedes dejar planteado acá.

list_notas = [15, 21, 24, 40, 13, 14, 18, 17, 14.5]

#Mostrar la lista original completa
print("\nLista original\n", list_notas)

# Definir índices para rebanar
i = 3
j = 7

# Rebanar desde la posición i=3 hasta j=7 (excluye el índice 7)
print(f"\nInicio({i})-fin({j})\n", list_notas[i:j])

# Rebanar desde i=2 hasta el final de la lista
i = 2
print(f"\nInicio({i})-final\n", list_notas[i:])

# Rebanar desde el inicio hasta j=-3 (excluye los 3 últimos elementos)
j = -3
print(f"\nCominezo-fin({j})\n", list_notas[:j])

# Copiar toda la lista (del inicio al final)
print("\nToda la lista\n", list_notas[:])

# Rebanar con saltos de 2 en 2 elementos
print("\nRebanar saltando un paso\n", list_notas[::2])

# Rebanar los dos últimos elementos de la lista
print("\nRebanar dos elementos del extremo\n", list_notas[-2:])

# Rebanar todos los elementos excepto los dos últimos
print("\nCortar dos elementos del final\n", list_notas[:-2])

# Mostrar la lista en orden inverso
print("\nOrden Inverso\n", list_notas[::-1])

# Rebanar los dos primeros elementos en orden inverso
print("\nRebanar los dos primeros elementos en orden inverso\n", list_notas[1::-1])
# Out:
# Lista original
#  [15, 21, 24, 40, 13, 14, 18, 17, 14.5]
#
# Inicio(3)-fin(7)
#  [40, 13, 14, 18]
#
# Inicio(2)-final
#  [24, 40, 13, 14, 18, 17, 14.5]
#
# Cominezo-fin(-3)
#  [15, 21, 24, 40, 13, 14]
#
# Toda la lista
#  [15, 21, 24, 40, 13, 14, 18, 17, 14.5]
#
# Rebanar saltando un paso
#  [15, 24, 13, 18, 14.5]
#
# Rebanar dos elementos del extremo
#  [17, 14.5]
#
# Cortar dos elementos del final
#  [15, 21, 24, 40, 13, 14, 18]
#
# Orden Inverso
#  [14.5, 17, 18, 14, 13, 40, 24, 21, 15]
#
# Rebanar los dos primeros elementos en orden inverso
#  [21, 15]

# %% [markdown]
# # Actividad: Diferentes métodos usados en listas.
#
# De la unidad 10, sección 6.3 revise los métodos disponibles para usar sobre las listas.
#
# Aplique los métodos disponibles sobre la lista mostrada en la siguiente celda.
#
# Nota: usando el método **sort()** ordene de mayor a menor y viceversa (Si es necesario revise documentación adicional relacionada sobre este método)

# %%
# Aplique los métodos disponibles y agregue comentarios breves sobre su funcionamien to.

list_notas = [15, 21, 24, 40, 13, 14, 18, 13, 17, 14.5]
print("Lista orginal:")
print(list_notas)

x = 40

# .index(x): devuelve la primera posición (índice) donde aparece el valor x
print(f"\nBuscar un lugar (i) buscando un elemento en la lista ({x}):")
print(f"i = {list_notas.index(x)}")

x = 10

# .append(x): agrega el elemento x al final de la lista
list_notas.append(x)
print(f"\nAñade el elemento x ({x}) al final de la lista:")
print(list_notas)

x = 13

# .count(x): cuenta cuántas veces aparece el valor x en la lista
print(f"\nNumero de elemento x ({x}) en la lista:\n", list_notas.count(x))

new_list = [14, 15]

# .extend(lista): agrega todos los elementos de otra lista al final
list_notas.extend(new_list)
print(f"\nInsertar la lista {new_list} en la lista inicial:")
print(list_notas)

x = 30
i = 5

# .insert(i, x): inserta el valor x en la posición i
list_notas.insert(i, x)
print(f"\nAñade x ({x}) a la posición deseada i ({i}):")
print(list_notas)

x = 13 

# .remove(x): elimina la primera aparición del valor x
list_notas.remove(x)
print(f"\n Eliminar el elemento x ({x}) de la lista")
print(list_notas)

# Otra forma: usando 'del' con la posición del elemento (list.index(x))
del list_notas[list_notas.index(x)]
print(f"\n Eliminar el elemento x ({x}) de la lista usando la palabra clave 'del'")
print(list_notas)

# .pop(): elimina y devuelve el último elemento de la lista
list_notas.pop()
print(f"\nEliminar el último elemento de la lista usando .pop():")
print(list_notas)

j = 9 
# .pop(j): elimina y devuelve el elemento en la posición j
list_notas.pop(j)
print(f"\nEliminar el elemento j ({j}) de la lista usando .pop(j):")
print(list_notas)

# .sort(): ordena los elementos de la lista en orden ascendente por defecto
list_notas.sort()
print("\nOrdenar los elementos de la lista de forma ascendente, reverse = False (default):")
print(list_notas)

# .sort(reverse=True): ordena los elementos en orden descendente
list_notas.sort(reverse = True)
print("\nOrdenar los elementos de la lista de forma descendente, reverse = True:")
print(list_notas)
 
# .reverse(): invierte el orden actual de los elementos
list_notas.reverse()
print("\nOrden inverso de los elementos de la lista:")
print(list_notas)
# Out:
# Lista orginal:
# [15, 21, 24, 40, 13, 14, 18, 13, 17, 14.5]
#
# Buscar un lugar (i) buscando un elemento en la lista (40):
# i = 3
#
# Añade el elemento x (10) al final de la lista:
# [15, 21, 24, 40, 13, 14, 18, 13, 17, 14.5, 10]
#
# Numero de elemento x (13) en la lista:
#  2
#
# Insertar la lista [14, 15] en la lista inicial:
# [15, 21, 24, 40, 13, 14, 18, 13, 17, 14.5, 10, 14, 15]
#
# Añade x (30) a la posición deseada i (5):
# [15, 21, 24, 40, 13, 30, 14, 18, 13, 17, 14.5, 10, 14, 15]
#
#  Eliminar el elemento x (13) de la lista
# [15, 21, 24, 40, 30, 14, 18, 13, 17, 14.5, 10, 14, 15]
#
#  Eliminar el elemento x (13) de la lista usando la palabra clave 'del'
# [15, 21, 24, 40, 30, 14, 18, 17, 14.5, 10, 14, 15]
#
# Eliminar el último elemento de la lista usando .pop():
# [15, 21, 24, 40, 30, 14, 18, 17, 14.5, 10, 14]
#
# Eliminar el elemento j (9) de la lista usando .pop(j):
# [15, 21, 24, 40, 30, 14, 18, 17, 14.5, 14]
#
# ...

# %% [markdown]
# # Actividad: Crear diccionarios y guardarlos como archivo JSON.
#
# De la unidad 11 sección 4.6 revise el ejemplo mostrado.
#
# Genera un diccionario, sobre la información que deseas guardar como base de datos, desarrollo el código necesario para generar el archivo JSON, y también el código para cargar la información del archivo JSON.

# %%
# Third-party library
import json

# %%
# Espacio para desarrollar el código.

# Base de datos 
data_phys = {
  "velocity_ms": [25.5, 10.2, 33.8],
  "acceleration_ms2": [9.81, 4.5, 12.3],
  "mass_kg": [12.3, 5.6, 20.1],
  "force_n": [120.66, 25.2, 247.23],
  "energy_joules": [1542.1, 320.5, 4500.8],
  "momentum_kgms": [313.65, 57.12, 679.38],
  "distance_m": [100.0, 25.5, 250.75],
  "time_s": [4.0, 2.5, 6.3],
  "power_watts": [385.53, 128.2, 714.29],
  "frequency_hz": [60, 50, 75]
}


# Nombre del archivo a guardar
name = 'book1.json'

# Crear un archivo .json con open
with open(name, 'w') as f:
    json.dump(data_phys, f, indent = '\t')
print(f"Archivo guardado satisfactoriamente como {name}")


# Abrir y leer el archivo JSON
with open(name, "r") as f:
    data = json.load(f)   # Carga el contenido en un diccionario de Python

# Mostrar el contenido
print("Contenido del archivo JSON:")
print(type(data))

# Recorremos las claves del diccionario y mostramos cada una con sus valores
for key in data.keys():
    print(key, ":", data[key])
# Out:
# Archivo guardado satisfactoriamente como book1.json
# Contenido del archivo JSON:
# <class 'dict'>
# velocity_ms : [25.5, 10.2, 33.8]
# acceleration_ms2 : [9.81, 4.5, 12.3]
# mass_kg : [12.3, 5.6, 20.1]
# force_n : [120.66, 25.2, 247.23]
# energy_joules : [1542.1, 320.5, 4500.8]
# momentum_kgms : [313.65, 57.12, 679.38]
# distance_m : [100.0, 25.5, 250.75]
# time_s : [4.0, 2.5, 6.3]
# power_watts : [385.53, 128.2, 714.29]
# frequency_hz : [60, 50, 75]

# %% [markdown]
# # Actividad: Creación y manejo de tuplas.
#
# ## Instrucciones
#
# 1. Escriba una diferencia entre las tuplas y las listas.
# - **Las tuplas son inmutables**: no se pueden modificar, agregar o eliminar elementos después de su creación.
# - **Las listas son mutables**: se pueden modificar, agregar o eliminar elementos libremente.
#
# 2. Crear una tupla con varios elementos.
# 3. Usar el operador in para verificar si la tuple contiene determinado elemento.

# %%
# Espacio para desarrollar el código siguiendo las instrucciones.

# 2. Crear una tupla con varios elementos
mi_tupla = ("manzana", "banana", "cereza", 42, True)
print("Mi tupla es: \n", mi_tupla)

# 3. Usar el operador 'in' para verificar si un elemento está en la tupla
elemento_a_buscar = "banana"

if elemento_a_buscar in mi_tupla:
    print(f"'{elemento_a_buscar}' está en la tupla.")
else:
    print(f"'{elemento_a_buscar}' no está en la tupla.")

# Otro ejemplo con un valor que no está
elemento_a_buscar = "pera"

if elemento_a_buscar in mi_tupla:
    print(f"'{elemento_a_buscar}' está en la tupla.")
else:
    print(f"'{elemento_a_buscar}' no está en la tupla.")
# Out:
# Mi tupla es:
#  ('manzana', 'banana', 'cereza', 42, True)
# 'banana' está en la tupla.
# 'pera' no está en la tupla.

# %% [markdown]
# # Actividad: Revisión y manejo de listas bidimensionales.
#
# ## Instrucciones
#
# 1. Describa brevemente que entiende por lista bidimensional.
#
# Una lista bidimensional es una lista cuyos elementos son a su vez listas.Esto permite representar estructuras como matrices donde se puede acceder a los elementos usando dos índices: filas y columnas.
#
# 2. Crear una lista bidimensional.
# 3. Generar un doble loop para acceder de la lista bidimensional
# 4. Sumar todo los elementos de esta lista bidimensional.

# %%
# Espacio para desarrollar el código, escriba comentarias breves para explicar su funcionamiento.

# 2. Crear una lista bidimensional (matriz 3x3)
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Mostar la lista matriz
print("Matriz:")
for fila in matriz:
    print(fila)

# 3. Generar un doble loop para acceder a todos los elementos

print("\nAccediendo a cada elemento de la matriz:")
for i in range(len(matriz)):          # Recorre las filas
    for j in range(len(matriz[i])):   # Recorre las columnas
        print(f"matriz[{i}][{j}] = {matriz[i][j]}")

# 4. Sumar todos los elementos de la lista bidimensional
suma_total = 0
for fila in matriz:
    for elemento in fila:
        suma_total += elemento

print("\nSuma de todos los elementos de la matriz:", suma_total)
# Out:
# Matriz:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
#
# Accediendo a cada elemento de la matriz:
# matriz[0][0] = 1
# matriz[0][1] = 2
# matriz[0][2] = 3
# matriz[1][0] = 4
# matriz[1][1] = 5
# matriz[1][2] = 6
# matriz[2][0] = 7
# matriz[2][1] = 8
# matriz[2][2] = 9
#
# Suma de todos los elementos de la matriz: 45

# %% [markdown]
# # Actividad: Revision de los métodos usados en el manejo de diccionarios.
#
# ## Instrucciones
#
# 1. Crear un diccionario.
# 2. Testear los siguientes métodos para el majeo de diccionarios get(), keys(), values(), items(), pop(), clear()
# 3. Agregar un breve comentario sobre su funcionamiento.

# %%
# Espacio para desarrollar el código.

# 1. Crear un diccionario
mi_diccionario = {
    "nombre": "Alan",
    "edad": 22,
    "carrera": "Física",
    "ciudad": "Latacunga"
}

print("Diccionario original:")
print(mi_diccionario)

# 2. Testear los métodos

# .get(): obtiene el valor de una clave sin generar error si no existe
print("\nUsando get():")
print("Edad:", mi_diccionario.get("edad"))
print("País (clave no existente):", mi_diccionario.get("pais"))

# .keys(): devuelve todas las claves del diccionario
print("\nUsando keys():")
print(mi_diccionario.keys())

# .values(): devuelve todos los valores del diccionario
print("\nUsando values():")
print(mi_diccionario.values())

# .items(): devuelve pares (clave, valor) del diccionario
print("\nUsando items():")
print(mi_diccionario.items())

# .pop(): elimina una clave y devuelve su valor
valor_eliminado = mi_diccionario.pop("ciudad")
print(f"\nUsando pop(): se eliminó la clave 'ciudad' con valor {valor_eliminado}")
print("Diccionario después de pop():", mi_diccionario)

# .clear(): elimina todos los elementos del diccionario
mi_diccionario.clear()
print("\nUsando clear(): diccionario después de limpiar:")
print(mi_diccionario)
# Out:
# Diccionario original:
# {'nombre': 'Alan', 'edad': 22, 'carrera': 'Física', 'ciudad': 'Latacunga'}
#
# Usando get():
# Edad: 22
# País (clave no existente): None
#
# Usando keys():
# dict_keys(['nombre', 'edad', 'carrera', 'ciudad'])
#
# Usando values():
# dict_values(['Alan', 22, 'Física', 'Latacunga'])
#
# Usando items():
# dict_items([('nombre', 'Alan'), ('edad', 22), ('carrera', 'Física'), ('ciudad', 'Latacunga')])
#
# Usando pop(): se eliminó la clave 'ciudad' con valor Latacunga
# Diccionario después de pop(): {'nombre': 'Alan', 'edad': 22, 'carrera': 'Física'}
#
# Usando clear(): diccionario después de limpiar:
# {}
